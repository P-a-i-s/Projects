# %% [markdown]
# # Boards

# %%
import pandas as pd
Table_1 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 1.xlsx',header=[0,1,2])
Table_2 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 2.xlsx',header=[0,1,2])
Table_3 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 3.xlsx',header=[0,1,2])
Table_4 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 4.xlsx',header=[0,1,2])
Table_5 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 5.xlsx',header=[0,1,2])
Table_6 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 6.xlsx',header=[0,1,2])
Table_7 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 7.xlsx',header=[0,1,2])
Table_8 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 8.xlsx',header=[0,1,2])
Table_9 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 9.xlsx',header=[0,1,2])
Table_10 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 10.xlsx',header=[0,1,2])
Table_11 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 11.xlsx',header=[0,1,2])
Table_12 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 12.xlsx',header=[0,1,2])
Table_13 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 13.xlsx',header=[0,1,2])
Table_14 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 14.xlsx',header=[0,1,2])

# %%
Table_1
# Out:
#                                                    Table 1- Annual and Supplementary Examination Results - Regular Students - All Categories  \
#                                                                                                                                     Appeared
# Name of the Board                                                                                                                       Boys
# Central Board of Secondary Education, New Delhi                                                366035
# Council for the Indian School Certificate Exami...                                              29378
# Board of Intermediate Education, Andhra Pradesh                                                378591
# Assam Higher Secondary Education Council                                                        82250
# Banasthali Vidyapith, Rajasthan                                                                    29
# ...

# %%
Table_2
# Out:
#                                                    Table 2 -Annual and Supplementary Examination Results - Private Students - All Categories  \
#                                                                                                                                     Appeared
# Name of the Board                                                                                                                       Boys
# Central Board of Secondary Education, New Delhi                                                 22205
# Council for the Indian School Certificate Exami...                                               1261
# Board of Intermediate Education, Andhra Pradesh                                                145052
# Assam Higher Secondary Education Council                                                        16778
# Banasthali Vidyapith, Rajasthan                                                                     0
# ...

# %%
Table_3
# Out:
#                                                    Table 3 -Annual and Supplementary Examination Results - Regular + Private Students - All Categories  \
#                                                                                                                                               Appeared
# Name of the Board                                                                                                                                 Boys
# Central Board of Secondary Education, New Delhi                                                388240
# Council for the Indian School Certificate Exami...                                              30639
# Board of Intermediate Education, Andhra Pradesh                                                523643
# Assam Higher Secondary Education Council                                                        99028
# Banasthali Vidyapith, Rajasthan                                                                    29
# ...

# %%
Table_4
# Out:
#                                                    Table 4 -Annual and Supplementary Examination Results - Regular SC Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                                 21501
# Council for the Indian School Certificate Exami...                                                604
# Board of Intermediate Education, Andhra Pradesh                                                 59210
# Assam Higher Secondary Education Council                                                         6817
# Banasthali Vidyapith, Rajasthan                                                                     4
# ...

# %%
Table_5
# Out:
#                                                    Table 5 -Annual and Supplementary Examination Results - Private SC Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                                1160.0
# Council for the Indian School Certificate Exami...                                               57.0
# Board of Intermediate Education, Andhra Pradesh                                               33571.0
# Assam Higher Secondary Education Council                                                       1311.0
# Banasthali Vidyapith, Rajasthan                                                                   0.0
# ...

# %%
Table_6
# Out:
#                                                    Table 6 -Annual and Supplementary Examination Results - Regular + Private SC Students  \
#                                                                                                                                 Appeared
# Name of the Board                                                                                                                   Boys
# Central Board of Secondary Education, New Delhi                                               22661.0
# Council for the Indian School Certificate Exami...                                              661.0
# Board of Intermediate Education, Andhra Pradesh                                               92781.0
# Assam Higher Secondary Education Council                                                       8128.0
# Banasthali Vidyapith, Rajasthan                                                                   4.0
# ...

# %%
Table_7
# Out:
#                                                    Table 7 -Annual and Supplementary Examination Results - Regular ST Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                               10000.0
# Council for the Indian School Certificate Exami...                                              809.0
# Board of Intermediate Education, Andhra Pradesh                                               24509.0
# Assam Higher Secondary Education Council                                                      14778.0
# Banasthali Vidyapith, Rajasthan                                                                   1.0
# ...

# %%
Table_8
# Out:
#                                                    Table 8 -Annual and Supplementary Examination Results - Private ST Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                                 891.0
# Council for the Indian School Certificate Exami...                                               43.0
# Board of Intermediate Education, Andhra Pradesh                                               12741.0
# Assam Higher Secondary Education Council                                                       3762.0
# Banasthali Vidyapith, Rajasthan                                                                   0.0
# ...

# %%
Table_9
# Out:
#                                                    Table 9 -Annual and Supplementary Examination Results - Regular + Private ST Students  \
#                                                                                                                                 Appeared
# Name of the Board                                                                                                                   Boys
# Central Board of Secondary Education, New Delhi                                                 10891
# Council for the Indian School Certificate Exami...                                                852
# Board of Intermediate Education, Andhra Pradesh                                                 37250
# Assam Higher Secondary Education Council                                                        18540
# Banasthali Vidyapith, Rajasthan                                                                     1
# ...

# %%
Table_10
# Out:
#                                                    Annual and Supplementary Examination Results - Percentage-wise-All Categories  \
#                                                                                                                        Table 10
# Name of the Board                                                                                Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                                575091
# Council for the Indian School Certificate Exami...                                              54154
# Board of Intermediate Education, Andhra Pradesh                                                639467
# Assam Higher Secondary Education Council                                                       136654
# Banasthali Vidyapith, Rajasthan                                                                   328
# ...

# %%
Table_11
# Out:
#                                                    Annual and Supplementary Examination Results - Percentage-wise-SC Students  \
#                                                                                                                      Table 11
# Name of the Board                                                                             Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                                 35937
# Council for the Indian School Certificate Exami...                                               1067
# Board of Intermediate Education, Andhra Pradesh                                                 96785
# Assam Higher Secondary Education Council                                                        10170
# Banasthali Vidyapith, Rajasthan                                                                     8
# ...

# %%
Table_12
# Out:
#                                                    Annual and Supplementary Examination Results - Percentage-wise-ST Students  \
#                                                                                                                      Table 12
# Name of the Board                                                                             Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                                 15143
# Council for the Indian School Certificate Exami...                                               1487
# Board of Intermediate Education, Andhra Pradesh                                                 36574
# Assam Higher Secondary Education Council                                                        23432
# Banasthali Vidyapith, Rajasthan                                                                    29
# ...

# %%
Table_13
# Out:
#                                                    Table13: Stream-wise Results Annual & Supplementary - Regular + Private Students - All Categories  \
#                                                                                                              All Streams - Number of Students Passed
# Name of the Board                                                                                                                              Boys
# Central Board of Secondary Education, New Delhi                                              317489.0
# Council for the Indian School Certificate Exami...                                            29469.0
# Board of Intermediate Education, Andhra Pradesh                                              350623.0
# Assam Higher Secondary Education Council                                                      69442.0
# Banasthali Vidyapith, Rajasthan                                                                  29.0
# ...

# %%
Table_14
# Out:
#                                                    Table14: Share of Pass Out Students in Different Streams  \
#                                                                                                        Arts
# Name of the Board                                                                                     Boys
# Central Board of Secondary Education, New Delhi                                             16.123393
# Council for the Indian School Certificate Exami...                                           2.769012
# Board of Intermediate Education, Andhra Pradesh                                              6.098858
# Assam Higher Secondary Education Council                                                    76.024596
# Banasthali Vidyapith, Rajasthan                                                             62.068966
# Bihar Intermediate Education Council                                                        38.653914
# ...

# %% [markdown]
# # Open-Boards

# %%
Table_15 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 15.xlsx',header=[0,1,2])
Table_15
# Out:
#                                                    Table 15 - Higher Secondary Open School Examination Board Results  \
#                                                                                            Appeared - All Categories
# Name of the Board                                                                                               Boys
# National Institute of Open Schooling, New Delhi                                                139446
# State Open Schooling, Assam                                                                       475
# Chattisgarh State Open School                                                                    7628
# Madhya Pradesh State Open School Board of Secon...                                              35727
# Rajasthan  State Open School, Rajasthan                                                          5615
# Rabindra Mukta Vidyalaya (West Bengal State Ope...                                               6687
# ...

# %%
Table_16 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 16.xlsx',header=[0,1,2])
Table_16
# Out:
#                                                    Open School Examination Board Results - Percentage-wise-All Categories  \
#                                                                                                                  Table 16
# Name of the Board                                                                         Total Number of Students Passed
# National Institute of Open Schooling, New Delhi                                                133129
# State Open Schooling, Assam                                                                       401
# Chattisgarh State Open School                                                                    7781
# Madhya Pradesh State Open School Board of Secon...                                              17215
# Rajasthan  State Open School, Rajasthan                                                          3438
# Rabindra Mukta Vidyalaya (West Bengal State Ope...                                               3130
# ...

# %%
Table_17 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 17.xlsx',header=[0,1,2])
Table_17
# Out:
#                                                    Open School Examination Board Results - Percentage-wise-SC Students  \
#                                                                                                              Table 17
# Name of the Board                                                                      Total Number of Students Passed
# National Institute of Open Schooling, New Delhi                                                 14777
# State Open Schooling, Assam                                                                         0
# Chattisgarh State Open School                                                                    1284
# Madhya Pradesh State Open School Board of Secon...                                               1593
# Rajasthan  State Open School, Rajasthan                                                           505
# Rabindra Mukta Vidyalaya (West Bengal State Ope...                                                498
# ...

# %%
Table_18 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Table 18.xlsx',header=[0,1,2])
Table_18
# Out:
#                                                    Open School Examination Board Results - Percentage-wise-ST Students  \
#                                                                                                               Table 18
# Name of the Board                                                                      Total Number of Students Passed
# National Institute of Open Schooling, New Delhi                                                7667.0
# State Open Schooling, Assam                                                                       NaN
# Chattisgarh State Open School                                                                  1612.0
# Madhya Pradesh State Open School Board of Secon...                                             1880.0
# Rajasthan  State Open School, Rajasthan                                                         363.0
# Rabindra Mukta Vidyalaya (West Bengal State Ope...                                              208.0
# ...

# %% [markdown]
# # TS

# %%
Statement_1_12 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/TS - Statement 1 - HIGHER SECONDARY EXAMINATION RESULTS DURING 2005 - 2010.xlsx',header=[0,1,2])
Statement_1_12
# Out:
#      Statement 1 - HIGHER SECONDARY EXAMINATION RESULTS DURING 2005 - 2010  \
#                                                  Appeared - All Categories
# Year                                                                  Boys
# 2005                                          4423634.0
# 2006                                          5020748.0
# 2007                                          5186501.0
# 2008                                          5652764.0
# 2009                                          6116582.0
# 2010                                                NaN
#
#                                                                      \
#                           Passed - All Categories
# Year    Girls       Total                    Boys    Girls    Total
# 2005  3104976   7528610.0                 3007558  2376341  5383899
# 2006  3412045   8432793.0                 3507082  2624376  6131458
# 2007  3681654   8868155.0                 3666845  2899333  6566178
# ...

# %% [markdown]
# # Pass TS

# %%
Statement_2_12 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/TS - Statement 2 - HIGHER SECONDARY EXAMINATION PASS PERCENTAGE DURING 2005 - 2010.xlsx',header=[0,1,2])
Statement_2_12
# Out:
#      Statement 2 - HIGHER SECONDARY EXAMINATION PASS PERCENTAGE DURING 2005 - 2010  \
#                                                                     All Categories
# Year                                                                          Boys
# 2005                                               68.0
# 2006                                               69.9
# 2007                                               70.7
# 2008                                               68.4
# 2009                                               73.0
# 2010                                               72.7
#
#
#                  Scheduled Caste             Scheduled Tribe
# Year Girls Total            Boys Girls Total            Boys Girls Total
# 2005  76.5  71.5            58.6  64.1  60.7            54.4  63.0  57.4
# 2006  76.9  72.7            63.3  69.5  65.6            57.3  63.5  59.6
# 2007  78.8  74.0            66.4  72.9  69.0            58.6  63.4  60.4
# ...

# %% [markdown]
# # StudentFlow

# %%
Statement_3_12 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/TS - Statement 3 - Students movement from Class X onwards.xlsx',header=[0,1,2])
Statement_3_12
# Out:
#                            Statement 3 - Students movement from Class X onwards  \
#                                                                               .
#                                                                            Year
# I - Passed in Class X                                                    2006
# II - Enrolled in Class XI                                                2007
# III -Enrolled in Class XII                                               2008
# IV - Appeared in Class XII                                               2009
# V - Passed in Class XII                                                  2010
#
#                                                                      \
#                            I - Passed in Class X
#                                             Boys    Girls     Total
# I - Passed in Class X                    5428736  4079333   9508069
# II - Enrolled in Class XI                5798647  4546040  10344687
# ...

# %% [markdown]
# # RegularBoardPass%

# %%
Pass_Percentage2 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/XII2010 files/Pass Percentage.xlsx',header=[0])

# %%
Pass2 = Pass_Percentage2.set_index('Name of the Board')
Pass2
# Out:
#                                                          Pass%
# Name of the Board
# Jharkhand Academic Council, Ranchi                   53.524353
# J.K State Board of School Education                  57.352335
# Department of Pre-University Education, Karnataka    58.206432
# Board of Intermediate Education, Andhra Pradesh      64.628869
# Meghalaya Board of School Education                  65.693051
# Tripura Board of Secondary Education                 70.766060
# Punjab School Education Board, Mohali                71.941162
# Assam Higher Secondary Education Council             73.395725
# Council of Higher Secondary Education, Orissa        74.201138
# Nagaland Board of School Education                   74.579458
# Goa Board of Secondary & Higher Secondary Educa...   75.453152
# Maharashtra State Board of Secondary & Higher S...   75.867320
# Mizoram Board of School Education                    76.019281
# Uttranchal Shiksha Evm Pariksha Parishad, Ramnagar   76.591974
# ...
