# %%
import glob
import pandas as pd

# get data file names
path =r'/Users/nish/Downloads/Company Files/test'
filenames = glob.glob(path + "/*.csv")

dic = {}
flag = True

def retDataFrame(filename):   
    tDf1 = pd.read_csv(filename)
    tDf2 = tDf1.groupby('COMPANY_STATUS').size()
    tDf3 = tDf2.to_frame(name=None).T
    tDf4 = tDf3.rename(index={0: b[0]})
    return tDf4;

for filename in filenames:
    a=filename.split('_')
    b=a[6].split('.')
    if flag:
        mn_tble = retDataFrame(filename)
        flag = False
        continue
    dic[b[0]] = retDataFrame(filename)

# Concatenate all data into one DataFrame
mn_tble = pd.concat(dic.values())
mn_tble
# Out:
#                     ACTIVE  ACTIVE IN PROGRESS  AMALGAMATED  CONVERTED TO LLP  \
# Dadra Nagar Haveli     341                 NaN          6.0               NaN
# Haryana              21185                 3.0        124.0               4.0
# Punjab               15346                 3.0        121.0               3.0
# Goa                   4853                 NaN        157.0               3.0
# Chhattisgarh          6212                 1.0         13.0               4.0
# Kerala               24835                 6.0         98.0               2.0
# Bihar                12653                 6.0          4.0               2.0
# Tamil Nadu           69082                25.0       1057.0              35.0
# Chandigarh            7445                 NaN         35.0               1.0
# Jammu                 2318                 1.0         13.0               NaN
# Jharkhand             6430                 1.0          8.0               1.0
# Meghalaya              533                 NaN          4.0               NaN
# Delhi               197051                27.0       3078.0             189.0
# Assam                 5106                 NaN         65.0               5.0
# Madhya Pradesh       20753                 2.0         65.0              10.0
# Lakshadweep             10                 NaN          NaN               NaN
# Manipur                189                 1.0          NaN               NaN
# Uttar Pradesh        48079                 5.0        197.0              24.0
# West Bengal         137172                 3.0       3952.0             228.0
# Uttarakhand           3553                 NaN          3.0               NaN
# Andhra Pradesh       13397                 7.0         72.0               4.0
# Puducherry            1353                 1.0         23.0               NaN
# Nagaland               151                 NaN          1.0               NaN
# Gujarat              52550                 8.0       1063.0              78.0
# Arunachal Pradesh      183                 NaN          NaN               NaN
# Maharashtra         215447                71.0       4023.0             317.0
# Tripura                207                 NaN          1.0               NaN
# Telangana            51743                21.0        402.0              31.0
# Daman Diu              191                 NaN          6.0               NaN
# Karnataka            53761                 7.0        590.0              24.0
# Mizoram                 29                 NaN          NaN               NaN
# Odisha               11989                 1.0         56.0               3.0
# Himachal              3049                 NaN         28.0               NaN
#
#                     CONVERTED TO LLP AND DISSOLVED  DEFAULT  DISSOLVED  \
# Dadra Nagar Haveli                             1.0      NaN        NaN
# Haryana                                        9.0      NaN        2.0
# Punjab                                        15.0      NaN        1.0
# Goa                                           18.0      NaN        5.0
# Chhattisgarh                                  16.0      NaN        NaN
# Kerala                                         4.0      NaN     1434.0
# Bihar                                          2.0      NaN       14.0
# Tamil Nadu                                   103.0      NaN      805.0
# Chandigarh                                    17.0      1.0        NaN
# Jammu                                          NaN      NaN        3.0
# Jharkhand                                      4.0      NaN       10.0
# Meghalaya                                      NaN      NaN        NaN
# Delhi                                        532.0      NaN      109.0
# Assam                                          5.0      NaN        4.0
# Madhya Pradesh                                28.0      NaN        NaN
# Lakshadweep                                    NaN      NaN        NaN
# Manipur                                        NaN      NaN        NaN
# Uttar Pradesh                                 66.0      NaN        5.0
# West Bengal                                  457.0      NaN      613.0
# Uttarakhand                                    2.0      NaN        NaN
# Andhra Pradesh                                 8.0      NaN        NaN
# Puducherry                                     NaN      NaN        8.0
# Nagaland                                       NaN      NaN        NaN
# Gujarat                                      212.0      NaN       49.0
# Arunachal Pradesh                              NaN      NaN        NaN
# Maharashtra                                 1206.0      NaN     5765.0
# Tripura                                        NaN      NaN        NaN
# Telangana                                     24.0      NaN        1.0
# Daman Diu                                      1.0      NaN        NaN
# Karnataka                                     66.0      NaN      240.0
# Mizoram                                        NaN      NaN        NaN
# Odisha                                         NaN      NaN       57.0
# Himachal                                       2.0      NaN        NaN
#
#                     DORMANT  Dormant under section 455 of Companies Act, 2013  \
# Dadra Nagar Haveli     38.0                                               NaN
# Haryana              2167.0                                              24.0
# Punjab               2013.0                                               4.0
# Goa                   443.0                                               NaN
# Chhattisgarh          244.0                                               1.0
# Kerala               2212.0                                              25.0
# Bihar                1208.0                                               5.0
# Tamil Nadu          15405.0                                              12.0
# Chandigarh           1103.0                                               NaN
# Jammu                 978.0                                               NaN
# Jharkhand             614.0                                               NaN
# Meghalaya              13.0                                               NaN
# Delhi               28168.0                                              65.0
# Assam                 174.0                                               NaN
# Madhya Pradesh       1335.0                                               2.0
# Lakshadweep             NaN                                               NaN
# Manipur                17.0                                               NaN
# Uttar Pradesh        4327.0                                               7.0
# West Bengal           790.0                                              21.0
# Uttarakhand            82.0                                               NaN
# Andhra Pradesh       5390.0                                               NaN
# Puducherry            228.0                                               NaN
# Nagaland               25.0                                               NaN
# Gujarat             10843.0                                               7.0
# Arunachal Pradesh       9.0                                               NaN
# Maharashtra         33907.0                                              24.0
# Tripura                 5.0                                               NaN
# Telangana           17210.0                                               1.0
# Daman Diu              14.0                                               1.0
# Karnataka            7877.0                                               8.0
# Mizoram                 7.0                                               NaN
# Odisha                566.0                                               3.0
# Himachal              412.0                                               1.0
#
#                     LIQUIDATED  STRIKE OFF  UNDER LIQUIDATION  \
# Dadra Nagar Haveli         NaN        35.0                NaN
# Haryana                    1.0      2427.0               29.0
# Punjab                     NaN      8405.0              113.0
# Goa                        4.0      1227.0               11.0
# Chhattisgarh               NaN      1017.0                1.0
# Kerala                     NaN      8774.0              296.0
# Bihar                      1.0      2410.0               41.0
# Tamil Nadu               386.0     25382.0              283.0
# Chandigarh                 NaN      3932.0               68.0
# Jammu                      2.0       593.0               15.0
# Jharkhand                  3.0      1067.0               12.0
# Meghalaya                  NaN       316.0                1.0
# Delhi                     54.0     40966.0              689.0
# Assam                      1.0      2644.0               14.0
# Madhya Pradesh             2.0      7298.0               65.0
# Lakshadweep                NaN         NaN                NaN
# Manipur                    NaN       153.0                NaN
# Uttar Pradesh             16.0     11107.0              214.0
# West Bengal               26.0     38685.0              653.0
# Uttarakhand                3.0       743.0               14.0
# Andhra Pradesh             1.0      2061.0               53.0
# Puducherry                 NaN      1117.0                8.0
# Nagaland                   NaN       261.0                1.0
# Gujarat                    NaN     12939.0              570.0
# Arunachal Pradesh          NaN       234.0                2.0
# Maharashtra              517.0     29858.0             1272.0
# Tripura                    NaN        80.0                NaN
# Telangana                 18.0      6448.0              223.0
# Daman Diu                  1.0        49.0                2.0
# Karnataka                  1.0     14587.0              496.0
# Mizoram                    NaN        53.0                NaN
# Odisha                     1.0      5433.0               64.0
# Himachal                   NaN      1081.0               20.0
#
#                     UNDER PROCESS OF STRIKING OFF
# Dadra Nagar Haveli                           10.0
# Haryana                                     139.0
# Punjab                                      142.0
# Goa                                         632.0
# Chhattisgarh                                 15.0
# Kerala                                      219.0
# Bihar                                      3323.0
# Tamil Nadu                                 1853.0
# Chandigarh                                   63.0
# Jammu                                        69.0
# Jharkhand                                   770.0
# Meghalaya                                    69.0
# Delhi                                      1441.0
# Assam                                      1245.0
# Madhya Pradesh                              222.0
# Lakshadweep                                   NaN
# Manipur                                      36.0
# Uttar Pradesh                              1118.0
# West Bengal                                2452.0
# Uttarakhand                                 265.0
# Andhra Pradesh                              212.0
# Puducherry                                    8.0
# Nagaland                                     37.0
# Gujarat                                    2865.0
# Arunachal Pradesh                            61.0
# Maharashtra                                2300.0
# Tripura                                      40.0
# Telangana                                   918.0
# Daman Diu                                    33.0
# Karnataka                                   867.0
# Mizoram                                       7.0
# Odisha                                      228.0
# Himachal                                    130.0

# %% [markdown]
# #get data file names
# path =r'/Users/nish/Downloads/Company Files/test'
# filenames = glob.glob(path + "/*.csv")
#
# dic = {}
# flag = True
#
# def retDataFrame(filename):
#     tDf1 = pd.read_csv(filename)
#     tDf2 = tDf1.groupby('COMPANY_STATUS').size()
#     tDf3 = tDf2.to_frame(name=None).T
#     tDf4 = tDf3.rename(index={0: b[0]})
#     return tDf4;
#
# for filename in filenames:
#     a=filename.split('_')
#     b=a[6].split('.')
#     if flag:
#         mn_tble = retDataFrame(filename)
#         flag = False
#         continue
#     dic[b[0]] = retDataFrame(filename)
#
# #Concatenate all data into one DataFrame
# mn_tble = pd.concat(dic.values())
# mn_tble

# %%
path =r'/Users/nish/Downloads/Company Files/test'
filenames = glob.glob(path + "/*.csv")

dic = {}
flag = True

def retDataFrame(filename):   
    tDf1 = pd.read_csv(filename)
    tDf2 = tDf1.groupby('COMPANY_STATUS').size()
    tDf3 = tDf2.to_frame(name=None).T
    tDf4 = tDf3.rename(index={0: b[0]})
    return tDf4;

# %%
tDf4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b3a3349a680d> in <module>()
# ----> 1 tDf4
#
# NameError: name 'tDf4' is not defined

# %%
b
# Out:
# ['West Bengal', 'csv']

# %%
a
