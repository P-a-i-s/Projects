# %%
import pandas as pd

# %%
df=pd.read_excel('/Users/nish/pais-datascience/data/NLES/2016/Table-2- Estimated Population by Age Group-2013 & 14.xlsx',skiprows=[0,1],header=[0,1])
df.T
# Out:
#                                                                                                      0   \
# Unnamed: 0_level_0               Unnamed: 0_level_1                                                 NaN
# Age group                        Unnamed: 1_level_1                                          6-10 Years
# 2013                             ALL                                                             130896
# Unnamed: 3_level_0               SC                                                               23324
# Unnamed: 4_level_0               ST                                                             13019.5
# 2014                             All                                                             130648
# Unnamed: 6_level_0               SC                                                               23286
# Unnamed: 7_level_0               ST                                                             12970.8
# ...
