# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# #List of states
# Dadra_Haveli -
# Chandigarh
# Andaman
# Arunachal
# Assam
# Goa
# Daman
# Chattisgarh
# Lakshwadeep
# Jharkhand
# Jammu
# Himachal
# Haryana
# Madhya Pradesh
# Nagaland
# Mizoram
# Meghalaya
# Manipur
# Maharashtra
# Punjab
# Pondi
# Tripura
# Uttarkhand
# West Bengal
# Bihar
# TN - D
# AP
# Delhi - D
# Kerala - D
# Gujarat - D
# Odisha
# UP - D
# Telangana - D
# Karnataka - D

# %%
#Data Munging per state starting with Karnataka, all other states
#...info will be joined to this table to create MAIN TABLE:
df_company_status = df_karnataka.groupby('COMPANY_STATUS').size()
df_status=df_company_status.to_frame(name=None).T
df_main_table=df_status.rename(index={0: 'Karnataka'})

#Telangana
df_company_status = df_telangana.groupby('COMPANY_STATUS').size()
df_status_tel1 = df_company_status.to_frame(name=None).T
df_status_tel2 = df_status_tel1.rename(index={0: 'Telangana'})

#UP
df_company_status = df_up.groupby('COMPANY_STATUS').size()
df_status_up1 = df_company_status.to_frame(name=None).T
df_status_up2 = df_status_up1.rename(index={0: 'Uttar Pradesh'})

#Gujarat
df_company_status = df_gujarat.groupby('COMPANY_STATUS').size()
df_status_guj1 = df_company_status.to_frame(name=None).T
df_status_guj2 = df_status_guj1.rename(index={0: 'Gujarat'})

#Kerala
df_company_status = df_kerala.groupby('COMPANY_STATUS').size()
df_status_ker1 = df_company_status.to_frame(name=None).T
df_status_ker2 = df_status_ker1.rename(index={0: 'Kerala'})

#Delhi
df_company_status = df_delhi.groupby('COMPANY_STATUS').size()
df_status_del1 = df_company_status.to_frame(name=None).T
df_status_del2 = df_status_del1.rename(index={0: 'Delhi'})

#TN
df_company_status = df_tn.groupby('COMPANY_STATUS').size()
df_status_tn1 = df_company_status.to_frame(name=None).T
df_status_tn2 = df_status_tn1.rename(index={0: 'Tamil Nadu'})

#Dadra_Haveli - 
df_company_status = df_dadra.groupby('COMPANY_STATUS').size()
df_status_dadr1 = df_company_status.to_frame(name=None).T
df_status_dadr2 = df_status_dadr1.rename(index={0: 'Dadra'})

#Chandigarh
df_company_status = df_chandigarh.groupby('COMPANY_STATUS').size()
df_status_chand1 = df_company_status.to_frame(name=None).T
df_status_chand2 = df_status_chand1.rename(index={0: 'Chandigarh'})

#Andaman
df_company_status = df_andaman.groupby('COMPANY_STATUS').size()
df_status_and1 = df_company_status.to_frame(name=None).T
df_status_and2 = df_status_and1.rename(index={0: 'Andaman'})

# Arunachal
df_company_status = df_arunachal.groupby('COMPANY_STATUS').size()
df_status_arun1 = df_company_status.to_frame(name=None).T
df_status_arun2 = df_status_arun1.rename(index={0: 'Arunachal'})

#Assam
df_company_status = df_assam.groupby('COMPANY_STATUS').size()
df_status_assa1 = df_company_status.to_frame(name=None).T
df_status_assa2 = df_status_assa1.rename(index={0: 'Assam'})

# Goa
df_company_status = df_goa.groupby('COMPANY_STATUS').size()
df_status_goa1 = df_company_status.to_frame(name=None).T
df_status_goa2 = df_status_goa1.rename(index={0: 'Goa'})

# Daman
df_company_status = df_daman.groupby('COMPANY_STATUS').size()
df_status_dam1 = df_company_status.to_frame(name=None).T
df_status_dam2 = df_status_dam1.rename(index={0: 'Goa'})

# Chattisgarh
df_company_status = df_chattisgarh.groupby('COMPANY_STATUS').size()
df_status_chat1 = df_company_status.to_frame(name=None).T
df_status_chat2 = df_status_chat1.rename(index={0: 'Chattisgarh'})

#Lakshwadeep
df_company_status = df_lakshawadeep.groupby('COMPANY_STATUS').size()
df_status_laks1 = df_company_status.to_frame(name=None).T
df_status_laks2 = df_status_laks1.rename(index={0: 'Lakshwadeep'})

# Jharkhand
df_company_status = df_jharkhand.groupby('COMPANY_STATUS').size()
df_status_jhark1 = df_company_status.to_frame(name=None).T
df_status_jhark2 = df_status_jhark1.rename(index={0: 'Jharkhand'})

# Jammu
df_company_status = df_jammu.groupby('COMPANY_STATUS').size()
df_status_jamm1 = df_company_status.to_frame(name=None).T
df_status_jamm2 = df_status_jamm1.rename(index={0: 'Jammu'})

#Himachal
df_company_status = df_himachal.groupby('COMPANY_STATUS').size()
df_status_him1 = df_company_status.to_frame(name=None).T
df_status_him2 = df_status_him1.rename(index={0: 'Himachal'})

# Haryana
df_company_status = df_haryana.groupby('COMPANY_STATUS').size()
df_status_hary1 = df_company_status.to_frame(name=None).T
df_status_hary2 = df_status_hary1.rename(index={0: 'Haryana'})

# Madhya Pradesh
df_company_status = df_madhyapradesh.groupby('COMPANY_STATUS').size()
df_status_madh1 = df_company_status.to_frame(name=None).T
df_status_madh2 = df_status_madh1.rename(index={0: 'Madhya Pradesh'})

# Nagaland
df_company_status = df_nagaland.groupby('COMPANY_STATUS').size()
df_status_nag1 = df_company_status.to_frame(name=None).T
df_status_nag2 = df_status_nag1.rename(index={0: 'Nagaland'})

# Mizoram
df_company_status = df_mizoram.groupby('COMPANY_STATUS').size()
df_status_miz1 = df_company_status.to_frame(name=None).T
df_status_miz2 = df_status_miz1.rename(index={0: 'Mizoram'})

# Meghalaya
df_company_status = df_meghalaya.groupby('COMPANY_STATUS').size()
df_status_meg1 = df_company_status.to_frame(name=None).T
df_status_meg2 = df_status_meg1.rename(index={0: 'Meghalaya'})

# Manipur
df_company_status = df_manipur.groupby('COMPANY_STATUS').size()
df_status_mani1 = df_company_status.to_frame(name=None).T
df_status_mani2 = df_status_mani1.rename(index={0: 'Manipur'})

# Maharashtra
df_company_status = df_maharashtra.groupby('COMPANY_STATUS').size()
df_status_maha1 = df_company_status.to_frame(name=None).T
df_status_maha2 = df_status_maha1.rename(index={0: 'Maharashtra'})

# Punjab
df_company_status = df_punjab.groupby('COMPANY_STATUS').size()
df_status_punj1 = df_company_status.to_frame(name=None).T
df_status_punj2 = df_status_punj1.rename(index={0: 'Punjab'})

# Pondi
df_company_status = df_pondi.groupby('COMPANY_STATUS').size()
df_status_pudu1 = df_company_status.to_frame(name=None).T
df_status_pudu2 = df_status_pudu1.rename(index={0: 'Puducherry'})

# Tripura
df_company_status = df_tripura.groupby('COMPANY_STATUS').size()
df_status_trip1 = df_company_status.to_frame(name=None).T
df_status_trip2 = df_status_trip1.rename(index={0: 'Tripura'})

# Uttarkhand
df_company_status = df_uk.groupby('COMPANY_STATUS').size()
df_status_uk1 = df_company_status.to_frame(name=None).T
df_status_uk2 = df_status_uk1.rename(index={0: 'Uttarkhand'})

# West Bengal
df_company_status = df_westbengal.groupby('COMPANY_STATUS').size()
df_status_wesb1 = df_company_status.to_frame(name=None).T
df_status_wesb2 = df_status_wesb1.rename(index={0: 'West Bengal'})

# Bihar
df_company_status = df_bihar.groupby('COMPANY_STATUS').size()
df_status_biha1 = df_company_status.to_frame(name=None).T
df_status_biha2 = df_status_biha1.rename(index={0: 'Bihar'})

# AP
df_company_status = df_andhra.groupby('COMPANY_STATUS').size()
df_status_andp1 = df_company_status.to_frame(name=None).T
df_status_andp2 = df_status_andp1.rename(index={0: 'Andhra Pradesh'})

# Odisha
df_company_status = df_odisha.groupby('COMPANY_STATUS').size()
df_status_odis1 = df_company_status.to_frame(name=None).T
df_status_odis2 = df_status_odis1.rename(index={0: 'Odisha'})

# %%
df_final_table = df_main_table.append([df_status_dadr2,df_status_chand2,df_status_and2,df_status_arun2,df_status_assa2,df_status_goa2,df_status_dam2,df_status_chat2,df_status_laks2,df_status_jhark2,df_status_jamm2,df_status_jamm2,df_status_him2,df_status_hary2,df_status_madh2,df_status_nag2,df_status_miz2,df_status_meg2,df_status_mani2,df_status_maha2,df_status_punj2,df_status_pudu2,df_status_trip2,df_status_uk2,df_status_wesb2,df_status_biha2,df_status_andp2,df_status_odis2,df_status_tel2,df_status_up2,df_status_guj2,df_status_ker2,df_status_del2,df_status_tn2,])

df_final_table
# Out:
#                 ACTIVE  ACTIVE IN PROGRESS  AMALGAMATED  CONVERTED TO LLP  \
# Karnataka        53761                 7.0        590.0              24.0
# Dadra              341                 NaN          6.0               NaN
# Chandigarh        7445                 NaN         35.0               1.0
# Andaman            200                 2.0          NaN               NaN
# Arunachal          183                 NaN          NaN               NaN
# Assam             5106                 NaN         65.0               5.0
# Goa               4853                 NaN        157.0               3.0
# Goa                191                 NaN          6.0               NaN
# Chattisgarh       6212                 1.0         13.0               4.0
# Lakshwadeep         10                 NaN          NaN               NaN
# Jharkhand         6430                 1.0          8.0               1.0
# Jammu             2318                 1.0         13.0               NaN
# ...

# %%
df_final_table['RATIO_ACTIVE_DORMANT']=df_final_table['DORMANT']/df_final_table['ACTIVE']

# %%
df_final_table.sort_values(by='RATIO_ACTIVE_DORMANT',ascending=False)
# df.sort_values(by='reports', ascending=0)
# Out:
#                 ACTIVE  ACTIVE IN PROGRESS  AMALGAMATED  CONVERTED TO LLP  \
# Jammu             2318                 1.0         13.0               NaN
# Jammu             2318                 1.0         13.0               NaN
# Andhra Pradesh   13397                 7.0         72.0               4.0
# Telangana        51743                21.0        402.0              31.0
# Mizoram             29                 NaN          NaN               NaN
# Andaman            200                 2.0          NaN               NaN
# Tamil Nadu       69082                25.0       1057.0              35.0
# Gujarat          52550                 8.0       1063.0              78.0
# Puducherry        1353                 1.0         23.0               NaN
# Nagaland           151                 NaN          1.0               NaN
# Maharashtra     215447                71.0       4023.0             317.0
# Chandigarh        7445                 NaN         35.0               1.0
# ...

# %%
type(df_final)
# Out:
# pandas.core.frame.DataFrame

# %%
df_allstats = df.groupby('COMPANY_STATUS').size()
df_allstats
# Out:
# COMPANY_STATUS
# ACTIVE                                              137172
# ACTIVE IN PROGRESS                                       3
# AMALGAMATED                                           3952
# CONVERTED TO LLP                                       228
# CONVERTED TO LLP AND DISSOLVED                         457
# DISSOLVED                                              613
# DORMANT                                                790
# Dormant under section 455 of Companies Act, 2013        21
# LIQUIDATED                                              26
# STRIKE OFF                                           38685
# UNDER LIQUIDATION                                      653
# UNDER PROCESS OF STRIKING OFF                         2452
# dtype: int64

# %%
df_karnataka.groupby('COMPANY_STATUS').size()
# Out:
# COMPANY_STATUS
# ACTIVE                                              53761
# ACTIVE IN PROGRESS                                      7
# AMALGAMATED                                           590
# CONVERTED TO LLP                                       24
# CONVERTED TO LLP AND DISSOLVED                         66
# DISSOLVED                                             240
# DORMANT                                              7877
# Dormant under section 455 of Companies Act, 2013        8
# LIQUIDATED                                              1
# STRIKE OFF                                          14587
# UNDER LIQUIDATION                                     496
# UNDER PROCESS OF STRIKING OFF                         867
# dtype: int64

# %%
import glob
import pandas as pd

# get data file names
path =r'/Users/nish/Downloads/Company Files/test'
filenames = glob.glob(path + "/*.csv")

dic = {}
def retDataFrame(filename):   
    tDf1 = pd.read_csv(filename)
    tDf2 = tDf1.groupby('COMPANY_STATUS').size()
    tDf3 = tDf2.to_frame(name=None).T
    tDf4 = tDf3.rename(index={0: b[0]})
    return tDf4;

for filename in filenames:
    a=filename.split('_')
    b=a[6].split('.')
    dic[b[0]] = retDataFrame(filename)

# Concatenate all data into one DataFrame
mn_tble = pd.concat(dic.values())
mn_tble
# Out:
#                     ACTIVE  ACTIVE IN PROGRESS  AMALGAMATED  CONVERTED TO LLP  \
# Dadra Nagar Haveli     341                 NaN          6.0               NaN
# Haryana              21185                 3.0        124.0               4.0
# Punjab               15346                 3.0        121.0               3.0
# Andaman Nicobar        200                 2.0          NaN               NaN
# Goa                   4853                 NaN        157.0               3.0
# Chhattisgarh          6212                 1.0         13.0               4.0
# Kerala               24835                 6.0         98.0               2.0
# Bihar                12653                 6.0          4.0               2.0
# Tamil Nadu           69082                25.0       1057.0              35.0
# Chandigarh            7445                 NaN         35.0               1.0
# Jammu                 2318                 1.0         13.0               NaN
# ...

# %%
dic[b[0]] = retDataFrame(filename)
dic[b[0]]
# Out:
# COMPANY_STATUS  ACTIVE  ACTIVE IN PROGRESS  AMALGAMATED  CONVERTED TO LLP  \
# West Bengal     137172                   3         3952               228
#
# COMPANY_STATUS  CONVERTED TO LLP AND DISSOLVED  DISSOLVED  DORMANT  \
# West Bengal                                457        613      790
#
# COMPANY_STATUS  Dormant under section 455 of Companies Act, 2013  LIQUIDATED  \
# West Bengal                                                   21          26
#
# COMPANY_STATUS  STRIKE OFF  UNDER LIQUIDATION  UNDER PROCESS OF STRIKING OFF
# West Bengal          38685                653                           2452

# %%
x1= pd.DataFrame()
x1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
big_frame.columns
# Out:
# Index([u'CORPORATE_IDENTIFICATION_NUMBER', u'DATE_OF_REGISTRATION',
#        u'COMPANY_NAME', u'COMPANY_STATUS', u'COMPANY_CLASS',
#        u'COMPANY_CATEGORY', u'AUTHORIZED_CAPITAL', u'PAIDUP_CAPITAL',
#        u'REGISTERED_STATE', u'REGISTRAR_OF_COMPANIES',
#        u'PRINCIPAL_BUSINESS_ACTIVITY', u'REGISTERED_OFFICE_ADDRESS',
#        u'SUB_CATEGORY'],
#       dtype='object')

# %%
big_frame.head(3)
# Out:
#   CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# 0           U00339AN1986PLC007658             18/06/86
# 1           U01111AN1994PTC000046             14/06/94
# 2           U01111AN1997PTC000056             15/07/97
#
#                           COMPANY_NAME COMPANY_STATUS COMPANY_CLASS  \
# 0  HIGHTECH PISTON (KARNATAKA) LIMITED     STRIKE OFF        Public
# 1  RAMYGANS PLANTATION PRIVATE LIMITED        DORMANT       Private
# 2          ECO RESORTS PRIVATE LIMITED        DORMANT       Private
#
#             COMPANY_CATEGORY AUTHORIZED_CAPITAL PAIDUP_CAPITAL  \
# 0  Company Limited by Shares        5,00,000.00            NaN
# 1  Company Limited by Shares       10,00,000.00            NaN
# 2  Company Limited by Shares       10,00,000.00      10,000.00
#
#               REGISTERED_STATE REGISTRAR_OF_COMPANIES  \
# 0  Andaman and Nicobar Islands            RoC-Chennai
# 1  Andaman and Nicobar Islands            RoC-Chennai
# ...

# %%
df_fin = big_frame.groupby('COMPANY_STATUS').size()
df_fin1table = df_fin.to_frame(name=None).T
df_final=df_fin1table.rename(index={0: 'All States'})
df_final.T
# Out:
#                                                   All States
# COMPANY_STATUS
# ACTIVE                                                987396
# ACTIVE IN PROGRESS                                       202
# AMALGAMATED                                            15265
# CONVERTED TO LLP                                         968
# CONVERTED TO LLP AND DISSOLVED                          2798
# DEFAULT                                                    1
# DISSOLVED                                               9125
# DORMANT                                               137870
# Dormant under section 455 of Companies Act, 2013         211
# LIQUIDATED                                              1038
# STRIKE OFF                                            231387
# UNDER LIQUIDATION                                       5230
# UNDER PROCESS OF STRIKING OFF                          21789

# %%
#pull out indidvidual state Dataframes and create them in a new folder

big_frame.loc[big_frame['REGISTERED_STATE'] == 'Andaman and Nicobar Islands']
# Out:
#                             CORPORATE_IDENTIFICATION_NUMBER  \
# REGISTERED_STATE
# Andaman and Nicobar Islands           U00339AN1986PLC007658
# Andaman and Nicobar Islands           U61200AN2010PTC000147
# Andaman and Nicobar Islands           U61200AN2011PTC000149
# Andaman and Nicobar Islands           U61200AN2012PTC000184
# Andaman and Nicobar Islands           U62200AN2007PTC000227
# Andaman and Nicobar Islands           U62200AN2010PTC000129
# Andaman and Nicobar Islands           U63000AN2012PTC000175
# Andaman and Nicobar Islands           U63000AN2014PTC000236
# Andaman and Nicobar Islands           U63022AN1984PTC000013
# Andaman and Nicobar Islands           U63030AN2008PTC000097
# Andaman and Nicobar Islands           U63031AN1993PTC000042
# Andaman and Nicobar Islands           U63031AN1995PTC000049
# Andaman and Nicobar Islands           U63040AN1987PTC000024
# Andaman and Nicobar Islands           U63040AN1995PTC000050
# ...

# %%
#sort df_final_table.sort_values(by='RATIO_ACTIVE_DORMANT',ascending=False)
#populating additional columns df_final_table['RATIO_ACTIVE_DORMANT']=df_final_table['DORMANT']/df_final_table['ACTIVE']

# %%
#Viewing Pleasure

# sort the dataframe
big_frame.sort(columns=['REGISTERED_STATE'], inplace=True)
# set the index to be this and don't drop
big_frame.set_index(keys=['REGISTERED_STATE'], drop=False,inplace=True)
# get a list of names
names=big_frame['REGISTERED_STATE'].unique().tolist()
# now we can perform a lookup on a 'view' of the dataframe
Ass = big_frame.loc[big_frame.REGISTERED_STATE=='Karnataka']
Ass.head(2)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                  CORPORATE_IDENTIFICATION_NUMBER DATE_OF_REGISTRATION  \
# REGISTERED_STATE
# Karnataka                  U72200KA2010FTC054712             09/08/10
# Karnataka                  U72200KA2010FTC052518             14/02/10
#
#                                                   COMPANY_NAME COMPANY_STATUS  \
# REGISTERED_STATE
# Karnataka                CHROMAGIC VIDEO INDIA PRIVATE LIMITED         ACTIVE
# Karnataka         MOOG INDIA TECHNOLOGY CENTER PRIVATE LIMITED         ACTIVE
#
#                  COMPANY_CLASS           COMPANY_CATEGORY AUTHORIZED_CAPITAL  \
# REGISTERED_STATE
# Karnataka              Private  Company Limited by Shares       10,00,000.00
# Karnataka              Private  Company Limited by Shares    35,00,00,000.00
#
#                    PAIDUP_CAPITAL REGISTERED_STATE REGISTRAR_OF_COMPANIES  \
# ...
