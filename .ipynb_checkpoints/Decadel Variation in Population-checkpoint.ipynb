# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
col_names = ['a','b','State','Census Year', 'Persons','Absolute','Percentage','Males','Females']
dfa = pd.read_excel('/Users/nish/pais-datascience/data/density/Decadal Variation In Population Since 1901.xls',header=None,names=col_names,skiprows=[0,1,2,3,4,5])

# %%
dfb=dfa.set_index('State')
dfc=dfb.drop('a',axis=1)
dfd = dfc.drop('b',axis=1)
dfc=dfd.iloc[:467]
dfc.head()
dfc.to_csv('Decadel Variation.csv')
dfc
# Out:
#                              Census Year     Persons                Absolute  \
# State
# INDIA                             1901 $   238396327                     ---
# NaN                                 1911   252093390            + 13,697,063
# NaN                                 1921   251321213               - 772,177
# NaN                               1931 $   278977238             +27,656,025
# NaN                               1941 $   318660580             +39,683,342
# NaN                               1951 @   361088090             +42,420,485
# NaN                               1961 @   439234771             +77,682,873
# NaN                                 1971   548159652            +108,924,881
# NaN                             1981 #     683329097            +135,169,445
# NaN                               1991 +   846421039            +163,091,942
# NaN                              2001 ++  1028737436            +182,316,397
# ...
