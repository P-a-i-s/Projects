# %% [markdown]
# # BOARD

# %%
import pandas as pd

# %%
Table_1 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_1_ASE_Regular Students.xlsx',header=[0,1,2])

# %%
Table_1.head()
# Out:
#                                                    Table 1- Annual and Supplementary Examination Results - Regular Students - All Categories - Number of Students  \
#                                                                                                                                                          Appeared
# Name of the Board                                                                                                                                            Boys
# Central Board of Secondary Education, New Delhi                                                509343
# Council for the Indian School Certificate Exami...                                              63004
# Board of Secondary Education, Andhra Pradesh                                                   548335
# Board of Secondary Education Assam                                                             138704
# ...

# %%
Table_2 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_2_ASE_Private Students.xlsx',header=[0,1,2])

# %%
Table_2.head()
# Out:
#                                                    Table 2 -Annual and Supplementary Examination Results - Private Students - All Categories - Number of Students  \
#                                                                                                                                                          Appeared
# Name of the Board                                                                                                                                            Boys
# Central Board of Secondary Education, New Delhi                                                 12768
# Council for the Indian School Certificate Exami...                                                319
# Board of Secondary Education, Andhra Pradesh                                                   190658
# Board of Secondary Education Assam                                                              47371
# ...

# %%
Table_3 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_3_ASE_Reguar and Private Students.xlsx',header=[0,1,2])

# %%
Table_3.head()
# Out:
#                                                    Table 3 -Annual and Supplementary Examination Results - Regular + Private Students - All Categories  \
#                                                                                                                                               Appeared
# Name of the Board                                                                                                                                 Boys
# Central Board of Secondary Education, New Delhi                                                522111
# Council for the Indian School Certificate Exami...                                              63323
# Board of Secondary Education, Andhra Pradesh                                                   738993
# Board of Secondary Education Assam                                                             186075
# Assam Sanskrit Board                                                                             3600
#
# ...

# %%
Table_4 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_4_ASE_Regular SC Students.xlsx',header=[0,1,2])

# %%
Table_4.head()
# Out:
#                                                    Table 4 -Annual and Supplementary Examination Results - Regular SC Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                                 30104
# Council for the Indian School Certificate Exami...                                               2134
# Board of Secondary Education, Andhra Pradesh                                                   102025
# Board of Secondary Education Assam                                                              10402
# Assam Sanskrit Board                                                                              900
#
#                                                                      \
#
# ...

# %%
Table_5 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_5_ASE_Private SC Students.xlsx',header=[0,1,2])

# %%
Table_5.head()
# Out:
#                                                    Table 5 -Annual and Supplementary Examination Results - Private SC Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                                1035.0
# Council for the Indian School Certificate Exami...                                               18.0
# Board of Secondary Education, Andhra Pradesh                                                  44099.0
# Board of Secondary Education Assam                                                             2485.0
# Assam Sanskrit Board                                                                            400.0
#
#                                                                     \
#
# ...

# %%
Table_6 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_6_Regular and Private Students.xlsx',header=[0,1,2])

# %%
Table_6.head()
# Out:
#                                                    Table 6 -Annual and Supplementary Examination Results - Regular + Private SC Students  \
#                                                                                                                                 Appeared
# Name of the Board                                                                                                                   Boys
# Central Board of Secondary Education, New Delhi                                                 31139
# Council for the Indian School Certificate Exami...                                               2152
# Board of Secondary Education, Andhra Pradesh                                                   146124
# Board of Secondary Education Assam                                                              12887
# Assam Sanskrit Board                                                                             1300
#
# ...

# %%
Table_7 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_7_Regular ST Students.xlsx',header=[0,1,2])

# %%
Table_7.head()
# Out:
#                                                    Table 7 -Annual and Supplementary Examination Results - Regular ST Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                               15948.0
# Council for the Indian School Certificate Exami...                                             1831.0
# Board of Secondary Education, Andhra Pradesh                                                  37937.0
# Board of Secondary Education Assam                                                            19545.0
# Assam Sanskrit Board                                                                            520.0
#
#                                                                       \
#
# ...

# %%
Table_8 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_8_Private ST Students.xlsx',header=[0,1,2])

# %%
Table_8.head()
# Out:
#                                                    Table 8 -Annual and Supplementary Examination Results - Private ST Students  \
#                                                                                                                       Appeared
# Name of the Board                                                                                                         Boys
# Central Board of Secondary Education, New Delhi                                                1019.0
# Council for the Indian School Certificate Exami...                                               23.0
# Board of Secondary Education, Andhra Pradesh                                                  13263.0
# Board of Secondary Education Assam                                                             6809.0
# Assam Sanskrit Board                                                                            198.0
#
#                                                                      \
#
# ...

# %%
Table_9 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_9_Regular and ST Students.xlsx',header=[0,1,2])

# %%
Table_9.head()
# Out:
#                                                    Table 9 -Annual and Supplementary Examination Results - Regular + Private ST Students  \
#                                                                                                                                 Appeared
# Name of the Board                                                                                                                   Boys
# Central Board of Secondary Education, New Delhi                                               16967.0
# Council for the Indian School Certificate Exami...                                             1854.0
# Board of Secondary Education, Andhra Pradesh                                                  51200.0
# Board of Secondary Education Assam                                                            26354.0
# Assam Sanskrit Board                                                                            718.0
#
# ...

# %%
Big_table1 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Big_Table_students.xlsx',header=[0,1,2])

# %%
Big_table1
# Out:
#                                                    Table 1- Annual and Supplementary Examination Results - Regular Students - All Categories  \
#                                                                                                                                     Appeared
# Name of the Board                                                                                                                       Boys
# Central Board of Secondary Education, New Delhi                                                509343
# Council for the Indian School Certificate Exami...                                              63004
# Board of Secondary Education, Andhra Pradesh                                                   548335
# Board of Secondary Education Assam                                                             138704
# Assam Sanskrit Board                                                                             2100
# ...

# %%
Table_10 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_10_Results - Percentages -- All Categories.xlsx',header=[0,1,2])

# %%
Table_10
# Out:
#                                                    Annual and Supplementary Examination Results - Percentage-wise-All Categories  \
#                                                                                                                        Table 10
# Name of the Board                                                                                Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                                834999
# Council for the Indian School Certificate Exami...                                             110921
# Board of Secondary Education, Andhra Pradesh                                                  1098815
# Board of Secondary Education Assam                                                             224255
# Assam Sanskrit Board                                                                             3724
# ...

# %%
Table_11 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_11_Results - Percentage-wise-SC Students.xlsx',header=[0,1,2])

# %%
Table_11
# Out:
#                                                    Table 11 -Annual and Supplementary Examination Results - Percentage-wise-SC Students  \
#                                                                                                                               Table 11
# Name of the Board                                                                                       Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                                 51905
# Council for the Indian School Certificate Exami...                                               3527
# Board of Secondary Education, Andhra Pradesh                                                   203532
# Board of Secondary Education Assam                                                              14469
# Assam Sanskrit Board                                                                             2045
# ...

# %%
Table_12 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_12_Results - Percentage-wise-Private Students.xlsx',header=[0,1,2])

# %%
Table_12
# Out:
#                                                    Table 12 -Annual and Supplementary Examination Results - Percentage-wise-ST Students  \
#                                                                                                                               Table 12
# Name of the Board                                                                                       Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                               25479.0
# Council for the Indian School Certificate Exami...                                             3396.0
# Board of Secondary Education, Andhra Pradesh                                                  71971.0
# Board of Secondary Education Assam                                                            27675.0
# Assam Sanskrit Board                                                                            840.0
# ...

# %%
Big_table_2 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Big_Table_percentages.xlsx',header=[0,1,2])

# %%
Big_table_2
# Out:
#                                                    Table 10 -Annual and Supplementary Examination Results - Percentage-wise-All Categories  \
#                                                                                                                                  Table 10
# Name of the Board                                                                                          Total Number of Students Passed
# Central Board of Secondary Education, New Delhi                                                834999
# Council for the Indian School Certificate Exami...                                             110921
# Board of Secondary Education, Andhra Pradesh                                                  1098815
# Board of Secondary Education Assam                                                             224255
# Assam Sanskrit Board                                                                             3724
# ...

# %% [markdown]
# # OPEN BOARD

# %%
Table_13 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_13_Results - High School Open Board Results.xlsx',header=[0,1,2])

# %%
Table_13
# Out:
#                                                    Table 13 - High School Open Examination Board Results - 2010  \
#                                                                                       Appeared - All Categories
# Name of the Board                                                                                          Boys
# National Institute of Open Schooling, New Delhi                                                136293
# A.P. Open School Society, Hyderabad                                                             33117
# Chhattisgarh State Open School                                                                  24704
# M.P. State Open School Board of Secondary Educa...                                              66396
# Rajasthan State Open School, Rajasthan                                                          18867
# Rabindra Mukta Vidyalaya (West Bengal State Ope...                                              29758
# ...

# %%
Table_14 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_14_Results - Percentage-wise-All Categories.xlsx',header=[0,1,2])

# %%
Table_14
# Out:
#                                                    High School Open Examination Board Results - Percentage-wise-All Categories  \
#                                                                                                                       Table 14
# Name of the Board                                                                              Total Number of Students Passed
# National Institute of Open Schooling, New Delhi                                                137993
# A.P. Open School Society, Hyderabad                                                             41451
# Chhattisgarh State Open School                                                                  21266
# M.P. State Open School Board of Secondary Educa...                                              35629
# Rajasthan State Open School, Rajasthan                                                          11579
# ...

# %%
Table_15 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_15_Results - Percentage-wise-SC Students.xlsx',header=[0,1,2])

# %%
Table_15
# Out:
#                                                    High School Open Examination Board Results - Percentage-wise-SC Students  \
#                                                                                                                  Table 15 -
# Name of the Board                                                                           Total Number of Students Passed
# National Institute of Open Schooling, New Delhi                                                 16708
# A.P. Open School Society, Hyderabad                                                              9165
# Chhattisgarh State Open School                                                                   3210
# M.P. State Open School Board of Secondary Educa...                                               2666
# Rajasthan State Open School, Rajasthan                                                           2107
# ...

# %%
Table_16 = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/Table_16_Results -  Percentage-wise-ST Students.xlsx',header=[0,1,2])

# %%
Table_16
# Out:
#                                                    High School Open Examination Board Results - Percentage-wise-ST Students  \
#                                                                                                                    Table 16
# Name of the Board                                                                           Total Number of Students Passed
# National Institute of Open Schooling, New Delhi                                                 10400
# A.P. Open School Society, Hyderabad                                                              4240
# Chhattisgarh State Open School                                                                   5327
# M.P. State Open School Board of Secondary Educa...                                               3361
# Rajasthan State Open School, Rajasthan                                                           1600
# ...

# %% [markdown]
# # TS

# %%
TS = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/TS - Statement 1 - HIGH SCHOOL EXAMINATION RESULTS DURING 2005 - 2010.xlsx',header=[0,1,2])

# %%
TS
# Out:
#      Statement 1 - HIGH SCHOOL EXAMINATION RESULTS DURING 2005 - 2010  \
#                                             Appeared - All Categories
# Year                                                             Boys
# 2005                                            8090002
# 2006                                            8196746
# 2007                                            8490098
# 2008                                            8532240
# 2009                                            9837590
# 2010                                            9684041
#
#                                                                     \
#                         Passed - All Categories
# Year    Girls     Total                    Boys    Girls     Total
# 2005  5396738  13486740                 4964179  3645676   8609855
# 2006  5815061  14011807                 5428736  4079333   9508069
# 2007  6222331  14712429                 5798647  4546040  10344687
# ...

# %% [markdown]
# # T%S

# %%
T_S = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/TS - Statement 2 - HIGH SCHOOL EXAMINATION PASS PERCENTAGE DURING 2005 - 2010.xlsx',header=[0,1,2])

# %%
T_S
# Out:
#      Statement 2 - HIGH SCHOOL EXAMINATION PASS PERCENTAGE DURING 2005 - 2010  \
# Year                                                           All Categories
#                                                                          Boys
# 2005                                          61.361901
# 2006                                          66.230380
# 2007                                          68.298941
# 2008                                          64.954057
# 2009                                          65.344043
# 2010                                          72.585783
#
#                                                                   \
# Year                       Scheduled Caste
#           Girls      Total            Boys      Girls      Total
# 2005  67.553326  63.839408       53.287528  59.366555  55.576305
# 2006  70.151164  67.857550       58.862597  62.729698  60.383343
# 2007  73.060080  70.312570       62.127322  65.797794  63.633766
# ...

# %% [markdown]
# # Boardwise Pass Percentage

# %%
Pass_Percentage = pd.read_excel('/Users/nish/pais-datascience/data/Exam_data/Board/zBoard wise - Pass Percentage.xlsx')

# %%
Pass = Pass_Percentage.set_index('Name of the Board')

# %%
Pass
# Out:
#                                                         Pass%
# Name of the Board
# J.K State Board of School Education                 37.181621
# Meghalaya Board of School Education                 45.058501
# Tripura Board of Secondary Education                52.901801
# Assam Sanskrit Board                                53.521127
# Board of Secondary Education, Madhya Pradesh        56.430623
# Chhattisgarh Board of Secondary Education           56.657295
# Nagaland Board of School Education                  58.190006
# Board of Secondary Education Assam                  59.463896
# Board of Secondary Education, Manipur               61.329339
# Gujarat Secondary & Higher Secondary Education ...  65.391198
# Uttranchal Shiksha Evm Pariksha Parishad            65.857901
# Mizoram Board of School Education                   67.840568
# Bihar School Education Board                        70.418848
# UP Board of High School & Intermediate Education    72.172086
# ...
