# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sq_kms = pd.read_csv('/Users/nish/pais-datascience/data/Population data/Popl_sq_km.csv')

# %%
sq_km=sq_kms.set_index('States')
sq_km
df=sq_km['Population - Total'].values
df
df1=sq_km['Area sq kms'].values
df1
df2=sq_km[''].values
# Out:
# array([    30,  94163,  88752,  38852, 240928,  44212, 130060,  50362,
#         79716,  78438,   3702, 307713,  10486, 191791, 196244, 275045,
#        155707, 308252, 342239,  53483, 135192,  22429,  22327, 222236,
#         55673,  16579,   7096,  21081,  83743])

# %%
sq_km.head()
# Out:
#                Population - Total  Population - Males  Population - Females  \
# States
# LAKSHADWEEP                 64473               33123                 31350
# BIHAR                   104099452            54278157              49821295
# WEST BENGAL              91276115            46809027              44467088
# KERALA                   33406061            16027412              17378649
# UTTAR PRADESH           199812341           104480510              95331831
#
#                Area sq kms  Population per sq. km.
# States
# LAKSHADWEEP             30                    2149
# BIHAR                94163                    1106
# WEST BENGAL          88752                    1028
# KERALA               38852                     860
# UTTAR PRADESH       240928                     829

# %%
lon,lat = sq_km['Area sq kms'],sq_km['Population - Total']
# area, population = sq_km['Population - Males'], sq_km['Population - Females']

plt.figure(figsize=(15,6))
plt.scatter(lon,lat, c= (sq_km['Population per sq. km.']), cmap = 'plasma', s = lat/10000, alpha = 0.3)
plt.xlabel('Population')

# plt.xticks(rotation=90)

# plt.yticks(df1)
plt.ylabel('Area sq kms')
plt.colorbar(label='Population per sq. km.')
# plt.xscale('log')
# plt.tight_layout()
# plt.xlim(0,300000)
# plt.ylim(0,2.75)
# z = plt.subplot()
# for i, txt in enumerate(sq_km.index):
#     z.annotate(txt, ())
#     print i

# plt.legend()
# plt.annotate('States',xy=(100000.0,99991996.5,),xytext=(99999.25,99988885.0),arrowprops={'color':'blue'})
plt.show()
plt.savefig('pop_density.png')

# %%
sq_km.plot(subplots=True)
plt.xticks(rotation=90)
# plt.axis(('KERALA','KARNATAKA',))
# Out:
# (array([  0.,   5.,  10.,  15.,  20.,  25.,  30.]),
#  <a list of 7 Text xticklabel objects>)

# %%
sq_km['Population - Males'].plot(c='r',label='male')
sq_km['Population - Females'].plot(c='b',label='female')
plt.xticks(rotation=90)
# plt.yticks(np.log10(sq_km['Population - Total']))
# plt.tight_layout()
plt.show()

# %%
lon,lat = sq_km['Area sq kms'],sq_km['Population - Total']
# area, population = sq_km['Population - Males'], sq_km['Population - Females']

plt.figure(figsize=(15,6))
plt.scatter(lon,lat, c= (sq_km['Population per sq. km.']), cmap = 'plasma', s = , alpha = 0.3)
plt.xlabel('Population')

# plt.xticks(rotation=90)

# plt.yticks(df1)
plt.ylabel('Area sq kms')
plt.colorbar(label='Population per sq. km.')
# plt.xscale('log')
# plt.tight_layout()
# plt.xlim(0,300000)
# plt.ylim(0,2.75)
# z = plt.subplot()
# for i, txt in enumerate(sq_km.index):
#     z.annotate(txt, ())
#     print i

# plt.legend()
# plt.annotate('States',xy=(100000.0,99991996.5,),xytext=(99999.25,99988885.0),arrowprops={'color':'blue'})
plt.show()
plt.savefig('pop_density.png')
